# %%
#finding type of variable
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
a='10.2'
print(type(a))
# Out:
# <class 'str'>

# %%
a="10"
print(type(a))
# Out:
# <class 'str'>

# %%
a='sanket'
print(type(a))
# Out:
# <class 'str'>

# %%
age=10
print(age)
age=age+1
print(age)
# Out:
# 10
# 11

# %%
age=10
print(age)
age=age-1
print(age)
# Out:
# 10
# 9

# %%
a="10"
print(type(a))
b=int(a)
print(type(b))
# Out:
# <class 'str'>
# <class 'int'>

# %%
a="20"
print(type(a))
b=int(a)
print(type(b))
# Out:
# <class 'str'>
# <class 'int'>
