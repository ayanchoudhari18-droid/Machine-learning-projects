# %%
marks=(10,20,30,40)
print(len(marks))
print(min(marks))
print(max(marks))
print(sum(marks))
print(50 in marks)
print(marks[1:3])
# Out:
# 4
# 10
# 40
# 100
# False
# (20, 30)

# %%
demo=(10,20,30,[10,20,30],40,50)
demo[3][2]=100
print(demo)
# Out:
# (10, 20, 30, [10, 20, 100], 40, 50)

# %%
fruits={"APPLE","BANANA","CHERRY"}
fruits.add("MANGO")
fruits.add("APPLE")
print(fruits)
# Out:
# {'BANANA', 'CHERRY', 'MANGO', 'APPLE'}

# %%
fruits={"APPLE","BANANA","CHERRY"}
fruits.add("MANGO")
fruits.add("APPLE")
print(fruits)
# Out:
# {'BANANA', 'CHERRY', 'MANGO', 'APPLE'}

# %%
#add()
fruits={"apple","banana"}
fruits.add("cherry")
print(fruits)
#update
fruits={"apple","banana"}
fruits.update(["cherry","grape"])
print(fruits)
#remove
fruits={"apple","banana","cherry"}
# Out:
# {'cherry', 'banana', 'apple'}
# {'cherry', 'banana', 'apple', 'grape'}

# %%
a={1,2,3}
b={2,3,4}
print(a.union(b))
# Out:
# {1, 2, 3, 4}

# %%
a={1,2,3}
b={2,3,4}
print(a.intersection(b))
# Out:
# {2, 3}

# %%
a={1,2,3}
b={2,3,4}
print(a.difference(b))
# Out:
# {1}

# %%
python={"RAVI","ANITA","KIRAN","RAHUL"}
java={"KIRAN","RAHUL","SNEHA","MEENA"}
print(python.union(java))
print(python.intersection(java))
print(java.intersection(python))
print(python.difference(java))
# Out:
# {'MEENA', 'SNEHA', 'RAVI', 'KIRAN', 'ANITA', 'RAHUL'}
# {'KIRAN', 'RAHUL'}
# {'KIRAN', 'RAHUL'}
# {'RAVI', 'ANITA'}

# %%
your_list={"milk","bread","eggs","butter"}
friends_list={"bread","butter","jam","cheese"}
print(your_list.intersection(friends_list))
print(your_list.difference(friends_list))
print(friends_list.difference(your_list))
print(your_list.union(friends_list))
# Out:
# {'bread', 'butter'}
# {'eggs', 'milk'}
# {'jam', 'cheese'}
# {'bread', 'eggs', 'milk', 'jam', 'butter', 'cheese'}

# %%
#clear
student={'name':"jhon","age":20,"country":"USA"}
student.clear()
print(student)

#copy()
student={'name':"arvind","age":20,}
new_student=student.copy()
print(new_student)

#get
student={'name':"ravi","age":20,}
print(student.get("age"))
print(student.get("course","xyz"))

#items
student={'name':"ravi","age":20,}
print(student.items())

#keys()
student={'name':"ravi","age":20,}
print(student.keys())
# Out:
# {}
# {'name': 'arvind', 'age': 20}
# 20
# xyz
# dict_items([('name', 'ravi'), ('age', 20)])
# dict_keys(['name', 'age'])

# %%
marks={"math":90,"science":85,"english":88}

#items
print("student with marks:",marks.items())

#remove last inserted
marks.popitem()
print("after popitem:",marks)
# Out:
# student with marks: dict_items([('math', 90), ('science', 85), ('english', 88)])
# after popitem: {'math': 90, 'science': 85}

# %%
cart={"pen": 10,"book": 120,"pencil":"bag": 450}

product="book"
print("price of", product, "is:",cart.get(product,"not found"))

cart.setdefault("eraser",15)


removed("removed:",removed_item)
print("removed:",removed_item)


print("available products"befehuetwth)
# Out:
#   File "/tmp/ipython-input-2965715059.py", line 1
#     cart={"pen": 10,"book": 120,"pencil":"bag": 450}
#                                               ^
# SyntaxError: invalid syntax
