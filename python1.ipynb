# %%
num_str="10"
num_int=int(num_str)
print(num_int)
# Out:
# 10

# %%
num_str="3.142"
num_float=float(num_str)
print(num_float)
# Out:
# 3.142

# %%
zero=0
bool_zero=bool(zero)
print(bool_zero)
# Out:
# False

# %%
non_zero=42
bool_non_zero=bool(non_zero)
print(bool_non_zero)
# Out:
# True

# %%
num_int=10
num_str=str(num_int)
print(num_str)
# Out:
# 10

# %%
a=input("enter a number")
print(a)
# Out:
# enter a number10
# 10

# %%
a=int(input("enter a string"))
print(type(a))
# Out:
# enter a string44
# <class 'int'>

# %%
a="HELLO"
b="HELLO"
print(a[-3])
# Out:
# L

# %%
a="sanket"
b="sanket"
print(a[-1])
# Out:
# t

# %%
g="jklopuy"
f="jklopuy"
print(a[-1])
# Out:
# t

# %%
a="Ayan"
b="Choudhari"
print(a+b)
# Out:
# AyanChoudhari

# %%
s="dar ki "
print(s[3:6])
# Out:
#  ki

# %%
t="..."
print(len(t))
# Out:
# 468

# %%
g= "my name is sanket"
print(len(g))
# Out:
# 17

# %%
f= " The quick brown fox jump over the lazy dog.The dog is not lazy after all! "
print(f.lower())

print(f.upper())

space=f.strip()
print(space)


g=f.replace("dog","cat")
print(g)


h=f.count("dog")
print(h)

v=f.title()
print(v)
# Out:
#  the quick brown fox jump over the lazy dog.the dog is not lazy after all!
#  THE QUICK BROWN FOX JUMP OVER THE LAZY DOG.THE DOG IS NOT LAZY AFTER ALL!
# The quick brown fox jump over the lazy dog.The dog is not lazy after all!
#  The quick brown fox jump over the lazy cat.The cat is not lazy after all!
# 2
#  The Quick Brown Fox Jump Over The Lazy Dog.The Dog Is Not Lazy After All!
