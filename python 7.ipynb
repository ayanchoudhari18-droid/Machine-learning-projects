# %%
print("Hello")
def greet():
    print("HELLO,WELCOME TO PYTHON!")

print("BYE")
greet()
# Out:
# Hello
# BYE
# HELLO,WELCOME TO PYTHON!

# %%
def Arth():
   a=100
   b=200
   c=a+b
print("BYE")
Arth()
# Out:
# BYE

# %%
del print
def Arth(a,b):
  c=a+b
  print(c)

Arth(1,2)

# %%
#exmple for function with parameter in return type
def Arth(a,b):
  return a+b

res=Arth(1,2)
print(res)
# Out:
# 3

# %%
def add(a,b):
  return a+b
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
result=add(a,b)
print("sum:",result)
# Out:
# Enter first number:12
# Enter second number:10
# sum: 22

# %%
def add(a,b):
  return a+b
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
result =add(a,b)
print("sum:",result)

def substraction(a,b):
  return a-b
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
result=substraction(a,b)
print("substraction:",result)

def multiplication(a,b):
  return a*b
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
result=multiplication(a,b)
print("multiplication:",result)

def devide(a,b):
  if b!=0:
    return a/b
  else:
    return "Error:Division by zero"
  a=int(input("Enter first number:"))
  b=int(input("Enter second number:"))
  result=devide(a,b)
  print("devide:",result)
# Out:
# Enter first number:0
# Enter second number:12
# sum: 12
# Enter first number:11
# Enter second number:88
# substraction: -77
# Enter first number:11
# Enter second number:0
# multiplication: 0

# %%
def calculate_bill(price,quantity):
  total=price*quantity
  return total

item1=calculate_bill(50,3)
item2=calculate_bill(20,5)

print("item 1 bill:",item1)
print("item 2 bill:",item2)
# Out:
# item 1 bill: 150
# item 2 bill: 100

# %%
def check_even_odd(n):
  if n % 2 == 0:
    print(n,"is even")
  else:
    print(n,"is odd")

num = int(input("Enter a number: "))
check_even_odd(num)
# Out:
# Enter a number: 4
# 4 is even

# %%
import time

current_time= time.time()
print("current time:",current_time)
# Out:
# current time: 1771044743.9036133

# %%
current_time= time.ctime()
print("current time:",current_time)
# Out:
# current time: Sat Feb 14 04:52:23 2026

# %%
import time
print("hello")
time.sleep(0.1)
print("weicome after five seconds")
# Out:
# hello
# weicome after five seconds

# %%
import time

current_time=time.localtime()

print("full date& time:",time.strftime("%Y-%m-%d %H:%M:%S",current_time))
print("only date:",time.strftime("%Y-%m-%d",current_time))
print("only time:",time.strftime("%I:%M:%P",current_time))
print("day name:",)
# Out:
# full date& time: 2026-02-14 04:52:55
# only date: 2026-02-14
# only time: 04:52:am
# day name:
